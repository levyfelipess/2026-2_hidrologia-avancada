# %%
# instalar dependências python
import sys
# !{sys.executable} -m pip install geopandas

# %%
import shp2asc

# %%
caminho_shp = "shapes/bacia_fronteiras_wgs84.shp"  # 34750000.shp ou bacia_fronteiras_wgs84.shp
pasta_saida = "./"

# %%
shp2asc.converter_shape(
    caminho_shp,
    pasta_saida,
    formato="asc",
    passo=1
)
# Out:
# ASC salvo: ./bacia_fronteiras_wgs84.asc
# Arquivo: bacia_fronteiras_wgs84.shp
# Geometrias: 1
# Total de coordenadas: 17411
# CRS: EPSG:4326
